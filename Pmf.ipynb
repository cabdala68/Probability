# %% [markdown]
# <a href="https://colab.research.google.com/github/cabdala68/Probability/blob/main/Pmf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Problem:**
#
# Bir meyve dükkanımız olduğunu ve her 10 dakikada bir dükkana ortalama 3 müşteri geldiğini varsayalım. Ortalama değeri 3 veya **λ = 3** 'tür.
#
# Önümüzdeki 10 dakika içinde 5 müşterinin gelmesi olasılığı nedir?

# %% [markdown]
# **Çözüm**
#
# PMF-Poison notasyonu şu şekildedir
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Poisson Distribution:**
#
# Belirli bir sayıda olayın sabit bir zaman aralığında meydana gelme olasılığını, bu olayların bilinen sabit bir ortalama hızda ve birbirinden bağımsız olarak meydana gelmesi durumunda verir.

# %%
#Importing the required modules
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import poisson
 
#Applying the poisson class methods
x = np.arange(0,10)
pmf = poisson.pmf(x,3)
 
#Visualizing the results
sb.set_style('whitegrid')
plt.vlines(x ,0, pmf, colors='k', linestyles='-', lw=6)
plt.ylabel('Probability')
plt.xlabel('ARALIK')
plt.show()
